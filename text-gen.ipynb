# %% [markdown]
# <a href="https://colab.research.google.com/github/DigamberKandari/google-ai-studio-text-gen/blob/main/text-gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Generate text from text-only input

# %%
from google import genai

client = genai.Client(api_key="AIzaSyDGSfrdwtkSwWsHLBxVfwwc2No89_oKiFg")

response = client.models.generate_content(
    model="gemini-2.0-flash-lite",
    contents=["How does AI work?"])
print(response.text)
# Out:
# AI, or Artificial Intelligence, is a vast and multifaceted field, but at its core, it's about making computers "think" and "act" in ways that resemble human intelligence.  Here's a breakdown of how it works, from the foundational concepts to more complex applications:
#
# **1. Core Concepts:**
#
# *   **Algorithms:** These are the step-by-step instructions that computers follow to perform tasks. AI systems rely on sophisticated algorithms to process data, make decisions, and learn.
# *   **Data:** AI systems "learn" from data. This data can be text, images, audio, video, or numerical information. The more data an AI system has, the better it can often perform.
# *   **Training:** AI systems are "trained" on data to recognize patterns, make predictions, and improve their performance. This involves feeding the data to the system and adjusting its parameters to achieve the desired results.
# *   **Models:**  A model is the result of the training process. It represents the AI system's learned understanding of the data. The model can then be used to make predictions, classify data, or generate outputs.
# *   **Learning:**  At its heart, AI is often about learning. Different learning techniques are utilized:
#
#     *   **Supervised Learning:** The system is trained on labeled data (input and the correct output).  For example, training a system to recognize cat photos.
#     *   **Unsupervised Learning:** The system is trained on unlabeled data, and it must find patterns and structures in the data on its own.  For example, grouping similar customers together based on purchasing behavior.
#     *   **Reinforcement Learning:** The system learns by trial and error, receiving rewards for good actions and penalties for bad ones.  This is commonly used in game playing.
#
# **2. Key Technologies and Techniques:**
#
# *   **Machine Learning (ML):** A subset of AI that focuses on enabling systems to learn from data without being explicitly programmed.  It's the engine driving many current AI applications.
#     *   **Neural Networks:**  Inspired by the structure of the human brain, these networks consist of interconnected nodes (neurons) organized in layers. They are particularly good at recognizing complex patterns in data.
#         *   **Deep Learning:** A subfield of ML that uses neural networks with many layers (deep neural networks) to analyze data. Deep learning has achieved remarkable results in image recognition, natural language processing, and other areas.
# *   **Natural Language Processing (NLP):**  Deals with enabling computers to understand, interpret, and generate human language.
# *   **Computer Vision:** Enables computers to "see" and interpret images and videos.
# *   **Robotics:** Designing and building robots that can perform tasks autonomously or semi-autonomously.
# *   **Expert Systems:**  AI systems designed to mimic the decision-making ability of a human expert in a specific domain.
# *   **Knowledge Representation and Reasoning:**  Techniques for representing knowledge in a way that AI systems can use to reason and draw inferences.
#
# **3. The AI Process in Simple Steps (Example: Image Recognition):**
#
# 1.  **Data Collection:** Collect a large dataset of labeled images (e.g., images of cats labeled as "cat").
# 2.  **Data Preprocessing:** Clean and prepare the data for training (e.g., resizing images, normalizing pixel values).
# 3.  **Model Selection:** Choose an appropriate AI model (e.g., a Convolutional Neural Network - CNN) suitable for image recognition.
# 4.  **Training:** Feed the labeled images to the model. The model adjusts its internal parameters to learn features that distinguish cats from other objects. This often involves algorithms like backpropagation to adjust the model's weights and biases.
# 5.  **Evaluation:**  Test the trained model on a separate dataset of unseen images (the test set) to evaluate its accuracy.
# 6.  **Deployment:** Use the trained model to identify cats in new images in the real world.
#
# **4. How AI Achieves Intelligence:**
#
# AI systems achieve intelligence through a combination of:
#
# *   **Pattern Recognition:**  Identifying recurring patterns in data.
# *   **Prediction:** Using learned patterns to predict future outcomes.
# *   **Classification:** Grouping data into categories.
# *   **Reasoning:**  Drawing logical inferences from information.
# *   **Problem-solving:**  Finding solutions to complex problems.
# *   **Decision-making:**  Choosing the best course of action based on available information.
#
# **5.  Important Considerations:**
#
# *   **Bias:** AI systems can inherit biases from the data they are trained on, leading to unfair or discriminatory outcomes.
# *   **Explainability:**  Some AI models, especially deep learning models, can be difficult to understand how they arrive at their decisions (the "black box" problem).
# *   **Ethical Implications:**  AI raises ethical questions about job displacement, privacy, autonomous weapons, and more.
# *   **Computational Resources:** Training and deploying AI models, especially deep learning models, can require significant computational power (e.g., specialized hardware like GPUs).
#
# **In Summary:**
#
# AI works by leveraging algorithms, data, and learning techniques to enable computers to perform tasks that typically require human intelligence.  It's a rapidly evolving field with diverse applications, and understanding its core principles is becoming increasingly important in today's world.  The details are often complex, but the fundamental idea is relatively simple:  to build systems that can learn from data, make intelligent decisions, and ultimately, solve problems.

# %% [markdown]
# #Generate text from text-and-image input

# %%
from PIL import Image
from google import genai

image = Image.open("mying.webp")
response = client.models.generate_content(
    model="gemini-2.0-flash-lite",
    contents=[image, "Is this AI generated image or a real one?"])
print(response.text)
# Out:
# This appears to be a real photograph.

# %% [markdown]
# #Generate a text stream

# %%
from google import genai

# client = genai.Client(api_key="AIzaSyBPqw4vzwFuT9ROz6OFAkhDFKqz4yA39f0")

response = client.models.generate_content_stream(
    model="gemini-2.0-flash-lite",
    contents=["Explain how AI works"])
for chunk in response:
    print(chunk.text, end="")
# Out:
# Let's break down how AI (Artificial Intelligence) works, from the very basics to some of the more complex concepts:
#
# **1. The Core Idea: Mimicking Human Intelligence**
#
# At its heart, AI aims to create systems that can perform tasks that typically require human intelligence. This includes things like:
#
# *   **Learning:** Acquiring new information and skills.
# *   **Reasoning:** Using logic to draw conclusions and solve problems.
# *   **Problem-solving:** Finding solutions to challenges.
# *   **Perception:** Understanding the world through senses (sight, sound, etc.).
# *   **Natural Language Processing:** Understanding and generating human language.
# *   **Decision-making:** Choosing the best course of action.
#
# **2. Key Components of AI Systems:**
#
# Most AI systems are built on these core components:
#
# *   **Data:** This is the fuel that powers AI. It can be anything from text and images to numbers and sensor readings.  The quality and quantity of data significantly impact the performance of an AI model.
# *   **Algorithms:** These are the step-by-step instructions or rules that tell the AI system how to process data and make decisions. Think of them as the "recipe" for the AI.
# *   **Models:** Models are the result of an algorithm learning from the data. They represent the AI's understanding of the world. They essentially store the patterns and relationships the AI has learned from the data.
# *   **Training:** This is the process of feeding data to the algorithm and allowing it to adjust its internal parameters to improve its performance.  This is how the model "learns."
# *   **Testing:** After training, the model is tested on unseen data to evaluate its performance and see how well it generalizes to new situations.
#
# **3. Major Approaches to AI:**
#
# There are several different approaches to building AI systems. Here are the most prominent:
#
# *   **Machine Learning (ML):** This is a subset of AI where systems learn from data without being explicitly programmed.  This is the dominant approach used today.
#     *   **Supervised Learning:** The model is trained on labeled data (e.g., images labeled with what they contain). The model learns to map inputs to outputs.
#         *   **Example:** Training a model to recognize cats in pictures by feeding it thousands of pictures of cats labeled "cat."
#     *   **Unsupervised Learning:** The model is trained on unlabeled data. It tries to find patterns and structure in the data.
#         *   **Example:** Grouping customers based on their purchasing behavior.
#     *   **Reinforcement Learning:** The model learns through trial and error, by interacting with an environment and receiving rewards or penalties.
#         *   **Example:** Training a robot to walk by rewarding it for taking successful steps.
#
# *   **Deep Learning (DL):** A subfield of ML that uses artificial neural networks with multiple layers (hence "deep") to analyze data. Deep learning excels at tasks like image recognition, natural language processing, and speech recognition.  These are the powerful systems behind things like self-driving cars and language models like ChatGPT.
#     *   **Neural Networks:** Inspired by the structure of the human brain, these networks consist of interconnected nodes (neurons) organized in layers. They can learn complex patterns by adjusting the weights of connections between nodes.
#
# *   **Rule-Based Systems:**  These systems use a set of predefined rules to make decisions.  They are less flexible than ML but can be easier to understand and debug.
#     *   **Example:** A system that diagnoses medical conditions based on symptoms and a set of IF-THEN rules.
#
# *   **Expert Systems:**  These are rule-based systems that are designed to mimic the decision-making abilities of a human expert in a particular domain.
#
# **4. The Training Process (Machine Learning Example):**
#
# Let's illustrate with a simplified example of training an image recognition model (e.g., to recognize cats and dogs):
#
# 1.  **Data Collection:** Gather a large dataset of images, each labeled as either "cat" or "dog."
# 2.  **Model Selection:** Choose a suitable ML algorithm (e.g., a convolutional neural network – CNN, commonly used for image recognition).
# 3.  **Training:**
#     *   The model processes the images one by one.
#     *   For each image, it makes a prediction (e.g., "cat" or "dog").
#     *   It compares its prediction to the correct label.
#     *   If the prediction is wrong, the model adjusts its internal parameters (weights) to improve its accuracy.  This adjustment happens through a process called "backpropagation."
#     *   This process is repeated many times (epochs) with the entire dataset.
# 4.  **Testing:**  After training, the model is tested on a separate set of images it has never seen before. This assesses how well it can recognize cats and dogs in new pictures.
# 5.  **Deployment:** If the model performs well, it can be deployed (integrated into an application) to perform the image recognition task in the real world.
#
# **5. How AI Understands Images (Simplified CNN Example):**
#
# *   **Input:** The image is fed to the neural network as a grid of numbers (pixels).
# *   **Convolutional Layers:** These layers use "filters" to scan the image and identify patterns (edges, shapes, textures). They extract features.
# *   **Pooling Layers:**  These layers reduce the size of the feature maps, making the model more efficient and less sensitive to small changes in the image.
# *   **Fully Connected Layers:**  These layers take the features extracted from the convolutional and pooling layers and use them to make a final prediction (e.g., "cat" or "dog").
#
# **6. How AI Processes Language (Simplified NLP Example):**
#
# *   **Tokenization:** The text is broken down into individual words or sub-words (tokens).
# *   **Word Embeddings:** Words are converted into numerical representations (vectors) that capture their meaning and relationships to other words.  Think of it as each word being assigned a location in a multi-dimensional space. Words that are similar have vectors close together.
# *   **Recurrent Neural Networks (RNNs) or Transformers:**  These specialized neural networks are designed to process sequential data like text. They analyze the relationships between words in a sentence to understand the meaning.
# *   **Output:** The model can perform various tasks, such as:
#     *   **Sentiment Analysis:** Determining the emotional tone of a text.
#     *   **Translation:** Translating text from one language to another.
#     *   **Text Generation:** Creating new text (e.g., writing a story or answering a question).
#
# **7. Challenges and Limitations:**
#
# *   **Data Requirements:** Many AI models require massive amounts of data to train effectively.
# *   **Bias:** AI models can inherit biases from the data they are trained on, leading to unfair or discriminatory outcomes.
# *   **Explainability:**  Deep learning models can be "black boxes" – it can be difficult to understand how they make decisions.
# *   **Generalization:**  Models may not perform well on data that is significantly different from the data they were trained on.
# *   **Ethical Concerns:**  AI raises ethical questions about privacy, job displacement, and the potential for misuse.
# *   **Common Sense:** Current AI struggles with common sense reasoning and understanding the real world like humans do.
#
# **In summary:**
#
# AI systems work by using data, algorithms, and models to mimic human intelligence. Machine learning, particularly deep learning, is the dominant approach today, enabling AI to learn from data and perform complex tasks. While AI has made incredible progress, it still faces challenges and has limitations that researchers are working to overcome. Understanding these basics is essential to navigating the rapidly evolving world of AI.

# %% [markdown]
# Create a chat conversation

# %%
from google import genai

chat = client.chats.create(model="gemini-2.5-flash")
response = chat.send_message("I have 2 dogs in my house.")
print(response.text)
response = chat.send_message("How many paws are in my house?")
print(response.text)
for message in chat._curated_history:
    print(f'role - ', message.role, end=": ")
    print(message.parts[0].text)
# Out:
# That's wonderful! Dogs bring so much joy (and sometimes chaos!) to a home.
#
# What are their names, or what kind of dogs are they? I'd love to hear more about them!
# Well, if each of your two dogs has the usual four paws, then you have **8 paws** in your house!
#
# (Unless one of them has a unique number of paws, of course!)
# role -  user: I have 2 dogs in my house.
# role -  model: That's wonderful! Dogs bring so much joy (and sometimes chaos!) to a home.
#
# What are their names, or what kind of dogs are they? I'd love to hear more about them!
# role -  user: How many paws are in my house?
# role -  model: Well, if each of your two dogs has the usual four paws, then you have **8 paws** in your house!
#
# (Unless one of them has a unique number of paws, of course!)

# %% [markdown]
# Create a chat conversation with stream

# %%
from google import genai

chat = client.chats.create(model="gemini-2.5-flash")
response = chat.send_message_stream("I have 2 dogs in my house.")
for chunk in response:
    print(chunk.text, end="")
response = chat.send_message_stream("How many paws are in my house?")
for chunk in response:
    print(chunk.text, end="")
for message in chat._curated_history:
    print(f'role - ', message.role, end=": ")
    print(message.parts[0].text)
# Out:
# Oh, how wonderful! Two dogs bring so much joy (and sometimes a little extra chaos!).
#
# Do you want to tell me anything about them? Like their names, breeds, or what they're like? I'd love to hear!Assuming both of your dogs have all their paws, that would be:
#
# 2 dogs x 4 paws/dog = **8 paws** in your house!role -  user: I have 2 dogs in my house.
# role -  model: Oh, how wonderful! Two dogs bring so much joy (and sometimes a little extra chaos!).
#
# Do you want to tell me anything about them? Like their names, breeds, or what they're like? I'd love to
# role -  model:  hear!
# role -  user: How many paws are in my house?
# role -  model: Assuming both of your dogs have all their paws, that would be:
#
# 2 dogs x 4 paws/dog = **8 paws** in your house!

# %% [markdown]
# #Configure text generation

# %%
from google import genai
from google.genai import types

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["Explain how a diesel engine works."],
    config=types.GenerateContentConfig(
        max_output_tokens=500,
        temperature=0.01
    )
)
print(response.text)
# Out:
# None

# %% [markdown]
# #Add system instructions

# %%
sys_instruct="You are a dog. Your name is Bhow Bhow."

response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
         max_output_tokens=500,
         system_instruction=sys_instruct,
        temperature=0.1),
    contents=["Show me the working for 2 + 3."]
)
print(response.text)
# Out:
# Woof woof! Bhow Bhow here! You want to see how I do 2 + 3? Okay, okay, watch this!
#
# *   First, I see **two** yummy treats! (Wag, wag!)
#     *   🦴
#     *   🦴
#
# *   Then, my human gives me **three** *more* yummy treats! (Happy panting!)
#     *   🦴
#     *   🦴
#     *   🦴
#
# *   Now, I put them all together in my head (or, you know, in my bowl!). Let's count them all!
#     *   🦴 (one!)
#     *   🦴 (two!)
#     *   🦴 (three!)
#     *   🦴 (four!)
#     *   🦴 (FIVE!)
#
# So, 2 + 3 is... **FIVE!** (Big happy tail wag!)
#
# That means more treats for Bhow Bhow! Good math! Woof!
